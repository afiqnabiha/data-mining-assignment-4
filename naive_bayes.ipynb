# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#memasukan data latih
datalatih = pd.read_csv("Data.csv")
datalatih.head()
#Prestasi Siswa = 1 == Ya 
#Prestasi Siswa = 2 == Tidak
#Prestasi Sekolah = 1 == Cukup
#Prestasi Sekolah = 2 == Baik
# Out:
#                     SEKOLAH  BAHASA PRANCIS  BAHASA INGGRIS  BAHASA JEPANG  \
# 0          SMAN 302 JAKARTA              98              80             92
# 1         SMA IT BINA AMAL               85              89             94
# 2  SMA KRISTEN SATYA WACANA              80              82             87
# 3           SMAN 245 BANTEN              90              97             85
# 4          SMAN 17 SEMARANG              98              90             82
#
#    SAINS  PRESTASI SISWA  PRESTASI SEKOLAH
# 0     80               1                 1
# 1     84               2                 1
# 2     87               1                 2
# 3     94               1                 2
# 4     92               1                 2

# %%
datalatih.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SEKOLAH           9 non-null      object
#  1   BAHASA PRANCIS    9 non-null      int64
#  2   BAHASA INGGRIS    9 non-null      int64
#  3   BAHASA JEPANG     9 non-null      int64
#  4   SAINS             9 non-null      int64
#  5   PRESTASI SISWA    9 non-null      int64
#  6   PRESTASI SEKOLAH  9 non-null      int64
# dtypes: int64(6), object(1)
# memory usage: 632.0+ bytes

# %%
from sklearn.cluster import KMeans
#Memvisualkan persebaran data
plt.scatter(datalatih.SAINS, datalatih.SEKOLAH, s = 75, c = "c", marker = "o", alpha = 0.5)
plt.show()

# %%
x = datalatih.drop(["SEKOLAH"], axis=1)
x.head(11)
# Out:
#    BAHASA PRANCIS  BAHASA INGGRIS  BAHASA JEPANG  SAINS  PRESTASI SISWA  \
# 0              98              80             92     80               1
# 1              85              89             94     84               2
# 2              80              82             87     87               1
# 3              90              97             85     94               1
# 4              98              90             82     92               1
# 5              92              92             82     90               2
# 6              83              92             88     88               2
# 7              89              98             97     89               1
# 8              96              80             90     86               2
#
#    PRESTASI SEKOLAH
# 0                 1
# 1                 1
# 2                 2
# 3                 2
# 4                 2
# 5                 2
# 6                 1
# 7                 1
# 8                 1

# %%
y = datalatih["SEKOLAH"]
y.head(11)
# Out:
# 0            SMAN 302 JAKARTA
# 1           SMA IT BINA AMAL
# 2    SMA KRISTEN SATYA WACANA
# 3             SMAN 245 BANTEN
# 4            SMAN 17 SEMARANG
# 5              SMA 17 AGUSTUS
# 6            SMAN JUWONO PATI
# 7             SMAN 3 SEMARANG
# 8      SMA IT NASIMA SEMARANG
# Name: SEKOLAH, dtype: object
